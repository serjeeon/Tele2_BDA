# %%
sqoop export --connect jdbc:teradata://10.78.245.130/DATABASE=UAT_DM \
--username ILYASHENKO_GA --password PASS --table gi_subs_competitors_tmp --export-dir /user/hive/warehouse/developers.db/gi_rtk_lpr \
--input-fields-terminated-by "\t"
# Out:
# ...
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# 18/09/06 13:47:24 INFO sqoop.Sqoop: Running Sqoop version: 1.4.6-cdh5.10.2
# 18/09/06 13:47:24 WARN tool.BaseSqoopTool: Setting your password on the command-line is insecure. Consider using -P instead.
# 18/09/06 13:47:25 INFO teradata.TeradataManagerFactory: Loaded connector factory for 'Cloudera Connector Powered by Teradata' on version 1.6c5
# 18/09/06 13:47:25 INFO manager.SqlManager: Using default fetchSize of 1000
# 18/09/06 13:47:25 INFO options.ExtraOptions: Parsing extra arguments
# 18/09/06 13:47:25 INFO options.OptionsCompatibility: Checking options compatibility
# 18/09/06 13:47:25 INFO teradata.SchemaInjector: Using connection string: jdbc:teradata://10.78.245.130/DATABASE=UAT_DM
# 18/09/06 13:47:27 INFO tool.CodeGenTool: Beginning code generation
# 18/09/06 13:47:27 INFO teradata.TeradataManager: Converting table import to query: SELECT * FROM "gi_subs_competitors_tmp"
# ...
